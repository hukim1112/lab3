# %%
# %load_ext autoreload
# %autoreload 2
# %config Completer.use_jedi = False

# %%
import os
import cv2
import random
import numpy as np
import torch
import argparse

from edge_connect.src.config import Config
from edge_connect.src.edge_connect import EdgeConnect

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = ','.join(str(e) for e in [1])

# %%
import os
import yaml
class Config(dict):
    def __init__(self, config_path):
        with open(config_path, 'r') as f:
            self._yaml = f.read()
            self._dict = yaml.safe_load(self._yaml)
            self._dict['PATH'] = os.path.dirname(config_path)

    def __getattr__(self, name):
        if self._dict.get(name) is not None:
            return self._dict[name]

        if DEFAULT_CONFIG.get(name) is not None:
            return DEFAULT_CONFIG[name]

        return None

    def print(self):
        print('Model configurations:')
        print('---------------------------------')
        print(self._yaml)
        print('')
        print('---------------------------------')
        print('')


DEFAULT_CONFIG = {
    'MODE': 1,                      # 1: train, 2: test, 3: eval
    'MODEL': 1,                     # 1: edge model, 2: inpaint model, 3: edge-inpaint model, 4: joint model
    'MASK': 3,                      # 1: random block, 2: half, 3: external, 4: (external, random block), 5: (external, random block, half)
    'EDGE': 1,                      # 1: canny, 2: external
    'NMS': 1,                       # 0: no non-max-suppression, 1: applies non-max-suppression on the external edges by multiplying by Canny
    'SEED': 10,                     # random seed
    'GPU': [0],                     # list of gpu ids
    'DEBUG': 0,                     # turns on debugging mode
    'VERBOSE': 0,                   # turns on verbose mode in the output console

    'LR': 0.0001,                   # learning rate
    'D2G_LR': 0.1,                  # discriminator/generator learning rate ratio
    'BETA1': 0.0,                   # adam optimizer beta1
    'BETA2': 0.9,                   # adam optimizer beta2
    'BATCH_SIZE': 8,                # input batch size for training
    'INPUT_SIZE': 256,              # input image size for training 0 for original size
    'SIGMA': 2,                     # standard deviation of the Gaussian filter used in Canny edge detector (0: random, -1: no edge)
    'MAX_ITERS': 2e6,               # maximum number of iterations to train the model

    'EDGE_THRESHOLD': 0.5,          # edge detection threshold
    'L1_LOSS_WEIGHT': 1,            # l1 loss weight
    'FM_LOSS_WEIGHT': 10,           # feature-matching loss weight
    'STYLE_LOSS_WEIGHT': 1,         # style loss weight
    'CONTENT_LOSS_WEIGHT': 1,       # perceptual loss weight
    'INPAINT_ADV_LOSS_WEIGHT': 0.01,# adversarial loss weight

    'GAN_LOSS': 'nsgan',            # nsgan | lsgan | hinge
    'GAN_POOL_SIZE': 0,             # fake images pool size

    'SAVE_INTERVAL': 1000,          # how many iterations to wait before saving model (0: never)
    'SAMPLE_INTERVAL': 1000,        # how many iterations to wait before sampling (0: never)
    'SAMPLE_SIZE': 12,              # number of images to sample
    'EVAL_INTERVAL': 0,             # how many iterations to wait before model evaluation (0: never)
    'LOG_INTERVAL': 10,             # how many iterations to wait before logging training status (0: never)
}

# %%
config = Config("edge_connect/config.yml.example")

# %%
if torch.cuda.is_available():
    config.DEVICE = torch.device("cuda")
    torch.backends.cudnn.benchmark = True   # cudnn auto-tuner
else:
    config.DEVICE = torch.device("cpu")
# set cv2 running threads to 1 (prevents deadlocks with pytorch dataloader)
cv2.setNumThreads(0)

# initialize random seed
SEED = 10
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
np.random.seed(SEED)
random.seed(SEED)

# %%
from edge_connect.src.edge_model import EdgeRunner

# %%
config.TRAIN_FLIST = "./edge_connect/datasets/places_train.flist"
config.VAL_FLIST = "./edge_connect/datasets/places_val.flist"
config.TEST_FLIST = "./edge_connect/datasets/places_test.flist"

# %%
config.MASK = 1

# %%
# build the model and initialize
model = EdgeConnect(config)
model.load()
# Out:
# Loading EdgeModel generator...
# Loading EdgeModel discriminator...

# %%
model.edge_model

# %%
# model training
if config.MODE == 1:
    config.print()
    print('\nstart training...\n')
    model.train()
# Out:
# Model configurations:
# ---------------------------------
# MODE: 1             # 1: train, 2: test, 3: eval
# MODEL: 1            # 1: edge model, 2: inpaint model, 3: edge-inpaint model, 4: joint model
# MASK: 3             # 1: random block, 2: half, 3: external, 4: (external, random block), 5: (external, random block, half)
# EDGE: 1             # 1: canny, 2: external
# NMS: 1              # 0: no non-max-suppression, 1: applies non-max-suppression on the external edges by multiplying by Canny
# SEED: 10            # random seed
# GPU: [0]            # list of gpu ids
# DEBUG: 0            # turns on debugging mode
# VERBOSE: 0          # turns on verbose mode in the output console
#
# TRAIN_FLIST: ./datasets/places2_train.flist
# VAL_FLIST: ./datasets/places2_val.flist
# TEST_FLIST: ./datasets/places2_test.flist
#
# TRAIN_EDGE_FLIST: ./datasets/places2_edges_train.flist
# VAL_EDGE_FLIST: ./datasets/places2_edges_val.flist
# TEST_EDGE_FLIST: ./datasets/places2_edges_test.flist
#
# TRAIN_MASK_FLIST: ./datasets/masks_train.flist
# VAL_MASK_FLIST: ./datasets/masks_val.flist
# TEST_MASK_FLIST: ./datasets/masks_test.flist
#
# LR: 0.0001                    # learning rate
# D2G_LR: 0.1                   # discriminator/generator learning rate ratio
# BETA1: 0.0                    # adam optimizer beta1
# BETA2: 0.9                    # adam optimizer beta2
# BATCH_SIZE: 8                 # input batch size for training
# INPUT_SIZE: 256               # input image size for training 0 for original size
# SIGMA: 2                      # standard deviation of the Gaussian filter used in Canny edge detector (0: random, -1: no edge)
# MAX_ITERS: 2e6                # maximum number of iterations to train the model
#
# EDGE_THRESHOLD: 0.5           # edge detection threshold
# L1_LOSS_WEIGHT: 1             # l1 loss weight
# FM_LOSS_WEIGHT: 10            # feature-matching loss weight
# STYLE_LOSS_WEIGHT: 250        # style loss weight
# CONTENT_LOSS_WEIGHT: 0.1      # perceptual loss weight
# INPAINT_ADV_LOSS_WEIGHT: 0.1  # adversarial loss weight
#
# GAN_LOSS: nsgan               # nsgan | lsgan | hinge
# GAN_POOL_SIZE: 0              # fake images pool size
#
# SAVE_INTERVAL: 1000           # how many iterations to wait before saving model (0: never)
# SAMPLE_INTERVAL: 1000         # how many iterations to wait before sampling (0: never)
# SAMPLE_SIZE: 12               # number of images to sample
# EVAL_INTERVAL: 0              # how many iterations to wait before model evaluation (0: never)
# LOG_INTERVAL: 10              # how many iterations to wait before logging training status (0: never)
#
# ---------------------------------
#
#
# start training...
#
#
#
# Training epoch: 1
#    8000/1803460 [....................] - ETA: 16:02:25 - epoch: 1 - iter: 483000 - precision: 0.2100 - recall: 0.1189
# saving sample edge_connect/samples/edge/483000.png
#
# saving EdgeModel...
#
#   16000/1803460 [....................] - ETA: 15:58:44 - epoch: 1 - iter: 484000 - precision: 0.2297 - recall: 0.1061
# saving sample edge_connect/samples/edge/484000.png
#
# saving EdgeModel...
#
#   24000/1803460 [....................] - ETA: 15:53:59 - epoch: 1 - iter: 485000 - precision: 0.2411 - recall: 0.0989
# saving sample edge_connect/samples/edge/485000.png
#
# saving EdgeModel...
#
#   32000/1803460 [....................] - ETA: 15:49:17 - epoch: 1 - iter: 486000 - precision: 0.2417 - recall: 0.0972
# saving sample edge_connect/samples/edge/486000.png
#
# saving EdgeModel...
#
#   40000/1803460 [....................] - ETA: 15:44:42 - epoch: 1 - iter: 487000 - precision: 0.2438 - recall: 0.0951
# saving sample edge_connect/samples/edge/487000.png
#
# saving EdgeModel...
#
#   48000/1803460 [....................] - ETA: 15:40:17 - epoch: 1 - iter: 488000 - precision: 0.2447 - recall: 0.0940
# saving sample edge_connect/samples/edge/488000.png
#
# saving EdgeModel...
#
#   56000/1803460 [....................] - ETA: 15:35:56 - epoch: 1 - iter: 489000 - precision: 0.2458 - recall: 0.0929
# saving sample edge_connect/samples/edge/489000.png
#
# saving EdgeModel...
#
#   64000/1803460 [....................] - ETA: 15:31:41 - epoch: 1 - iter: 490000 - precision: 0.2466 - recall: 0.0924
# saving sample edge_connect/samples/edge/490000.png
#
# saving EdgeModel...
#
#   72000/1803460 [....................] - ETA: 15:27:27 - epoch: 1 - iter: 491000 - precision: 0.2461 - recall: 0.0922
# saving sample edge_connect/samples/edge/491000.png
#
# saving EdgeModel...
#
#   80000/1803460 [....................] - ETA: 15:23:08 - epoch: 1 - iter: 492000 - precision: 0.2460 - recall: 0.0921
# saving sample edge_connect/samples/edge/492000.png
#
# saving EdgeModel...
#
#   88000/1803460 [....................] - ETA: 15:18:49 - epoch: 1 - iter: 493000 - precision: 0.2458 - recall: 0.0919
# saving sample edge_connect/samples/edge/493000.png
#
# saving EdgeModel...
#
#   96000/1803460 [>...................] - ETA: 15:14:33 - epoch: 1 - iter: 494000 - precision: 0.2455 - recall: 0.0920
# saving sample edge_connect/samples/edge/494000.png
#
# saving EdgeModel...
#
#  104000/1803460 [>...................] - ETA: 15:10:15 - epoch: 1 - iter: 495000 - precision: 0.2443 - recall: 0.0926
# saving sample edge_connect/samples/edge/495000.png
#
# saving EdgeModel...
#
#  112000/1803460 [>...................] - ETA: 15:05:55 - epoch: 1 - iter: 496000 - precision: 0.2434 - recall: 0.0931
# saving sample edge_connect/samples/edge/496000.png
#
# saving EdgeModel...
#
#  120000/1803460 [>...................] - ETA: 15:01:38 - epoch: 1 - iter: 497000 - precision: 0.2421 - recall: 0.0938
# saving sample edge_connect/samples/edge/497000.png
#
# saving EdgeModel...
#
#  128000/1803460 [>...................] - ETA: 14:57:22 - epoch: 1 - iter: 498000 - precision: 0.2409 - recall: 0.0944
# saving sample edge_connect/samples/edge/498000.png
#
# saving EdgeModel...
#
#  136000/1803460 [>...................] - ETA: 14:53:03 - epoch: 1 - iter: 499000 - precision: 0.2399 - recall: 0.0950
# saving sample edge_connect/samples/edge/499000.png
#
# saving EdgeModel...
#
#  144000/1803460 [>...................] - ETA: 14:48:46 - epoch: 1 - iter: 500000 - precision: 0.2389 - recall: 0.0956
# saving sample edge_connect/samples/edge/500000.png
#
# saving EdgeModel...
#
#  152000/1803460 [>...................] - ETA: 14:44:27 - epoch: 1 - iter: 501000 - precision: 0.2379 - recall: 0.0962
# saving sample edge_connect/samples/edge/501000.png
#
# saving EdgeModel...
#
#  160000/1803460 [>...................] - ETA: 14:40:10 - epoch: 1 - iter: 502000 - precision: 0.2369 - recall: 0.0967
# saving sample edge_connect/samples/edge/502000.png
#
# saving EdgeModel...
#
#  168000/1803460 [>...................] - ETA: 14:35:54 - epoch: 1 - iter: 503000 - precision: 0.2362 - recall: 0.0971
# saving sample edge_connect/samples/edge/503000.png
#
# saving EdgeModel...
#
#  176000/1803460 [>...................] - ETA: 14:31:35 - epoch: 1 - iter: 504000 - precision: 0.2353 - recall: 0.0978
# saving sample edge_connect/samples/edge/504000.png
#
# saving EdgeModel...
#
#  184000/1803460 [=>..................] - ETA: 14:27:18 - epoch: 1 - iter: 505000 - precision: 0.2347 - recall: 0.0984
# saving sample edge_connect/samples/edge/505000.png
#
# saving EdgeModel...
#
#  192000/1803460 [=>..................] - ETA: 14:23:01 - epoch: 1 - iter: 506000 - precision: 0.2341 - recall: 0.0989
# saving sample edge_connect/samples/edge/506000.png
#
# saving EdgeModel...
#
#  198432/1803460 [=>..................] - ETA: 14:19:36 - epoch: 1 - iter: 506804 - precision: 0.2333 - recall: 0.0995

# %%
# model test
elif config.MODE == 2:
    print('\nstart testing...\n')
    model.test()

# %%
# eval mode
else:
    print('\nstart eval...\n')
    model.eval()
